# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
a=pd.read_excel("/content/drive/MyDrive/Bert/Release_Notes_v0_RawData.xlsx")

# %%
a
# Out:
#         ID     Project_Name Release_Number       Date    Label       Type  \
# 0      1.0  Mozilla Firefox           86.0 2021-02-23      new        new
# 1      2.0  Mozilla Firefox           86.0 2021-02-23    fixed      fixed
# 2      3.0  Mozilla Firefox           86.0 2021-02-23  changed    changed
# 3      4.0  Mozilla Firefox           86.0 2021-02-23    other  developer
# 4      5.0  Mozilla Firefox         85.0.2 2021-02-09    fixed      fixed
# ..     ...              ...            ...        ...      ...        ...
# 795  796.0            Slack          2.8.0 2017-09-11    fixed      fixed
# 796  797.0            Slack          2.7.1 2017-08-17    fixed      fixed
# 797  798.0            Slack          2.7.0 2017-08-01      new        new
# 798  799.0            Slack          2.7.0 2017-08-01    fixed      fixed
# 799  800.0            Slack          2.6.5 2017-07-12      new        new
#
#                                           Release_Note
# ...

# %%
a["Label"].unique()
# Out:
# array(['new', 'fixed', 'changed', 'other', 'unresolved'], dtype=object)

# %%
sutun_isimleri = ['Label', 'Release_Note']

# %%
veriseti = pd.DataFrame(data=a, columns=sutun_isimleri)
print(veriseti)
# Out:
#        Label                                       Release_Note
# 0        new  Firefox now supports simultaneously watching m...
# 1      fixed  Reader mode now works with local HTML pages. U...
# 2    changed  On Linux and Android, the protection to mitiga...
# 3      other  Inactive CSS tool is now showing a warning whe...
# 4      fixed      Fixed a deadlock during startup (bug 1679933)
# ..       ...                                                ...
# 795    fixed  Fixed: A few rare crashes when making a call a...
# 796    fixed  You're nearly finished signing in when suddenl...
# 797      new  File downloads are now pausable and – in perha...
# 798    fixed  On Windows 7, notifications have been made mor...
# 799      new  The certificate used by Windows to confirm tha...
#
# [800 rows x 2 columns]

# %%
# !pip install simpletransformers
# Out:
# ...
#      |████████████████████████████████| 248 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 312 kB 53.1 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 67.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 57.8 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 51.5 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 61.9 MB/s
# ...
#      |████████████████████████████████| 9.9 MB 35.8 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 67 kB 7.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 55.7 MB/s
# ...
#      |████████████████████████████████| 895 kB 59.4 MB/s
# ...
#      |████████████████████████████████| 144 kB 76.7 MB/s
# ...
#      |████████████████████████████████| 181 kB 70.8 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 134 kB 75.0 MB/s
# ...
#      |████████████████████████████████| 212 kB 69.0 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 52.1 MB/s
# ...

# %%
from simpletransformers.classification import ClassificationModel

# %%
a['labels'] = pd.factorize(a.Label)[0]

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(a, test_size=0.2, random_state=42)

# %%
import re
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords

# %%
ps = PorterStemmer()

stop = nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
for j in range(800):
    metin = re.sub("[^a-zA-Z]", " ",a["Release_Note"][j])
    metin = metin.lower()
    metin = metin.split()
    metin = [ps.stem(i) for i in metin if not i in set(stopwords.words("english"))]
    son_metin = " ".join(metin)
    a["Release_Note"][j]= son_metin
print(a["Release_Note"])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0      firefox support simultan watch multipl video p...
# 1      reader mode work local html page use screen re...
# 2      linux android protect mitig stack clash attack...
# 3      inact css tool show warn margin pad set intern...
# 4                               fix deadlock startup bug
#                              ...
# 795    fix rare crash make call screen share call bel...
# 796    nearli finish sign suddenli bonk brought back ...
# 797    file download pausabl perhap master stroke mat...
# 798    window notif made reliabl expens prefer longer...
# 799    certif use window confirm slack truli slack ex...
# Name: Release_Note, Length: 800, dtype: object

# %%
a["Release_Note"][0]
# Out:
# 'firefox support simultan watch multipl video pictur pictur today firefox introduc total cooki protect strict mode total cooki protect everi websit get cooki jar prevent cooki use track site site improv print function cleaner design better integr comput printer set new print preview screenshot firefox user canada credit card manag auto fill enabl'

# %%
train=train[["Release_Note","labels"]]
test=test[["Release_Note","labels"]]

# %%
train["Release_Note"]=train["Release_Note"].apply(lambda r: str(r))
train['labels']=train['labels'].astype(int)

# %%
model = ClassificationModel('bert', 'bert-base-uncased',
                            num_labels=5, use_cuda=False,
                            args={'reprocess_input_data': True, 'overwrite_output_dir': True, 
                                  'num_train_epochs': 10, 
                                    "train_batch_size": 64 , "fp16":False, 
                                     "output_dir": "./drive/MyDrive/Bert/bert_model"})
# Out:
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/420M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
model.train_model(train)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/640 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ...
# Running Epoch 14 of 15:   0%|          | 0/10 [00:00<?, ?it/s]
# (150, 0.46607359978059926)

# %%
result, model_outputs, wrong_predictions = model.eval_model(test)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# ...
# Running Evaluation:   0%|          | 0/20 [00:00<?, ?it/s]

# %%
predictions = model_outputs.argmax(axis=1)

# %%
actuals = test.labels.values

# %%
predictions[:]
# Out:
# array([2, 2, 1, 0, 3, 2, 4, 2, 1, 0, 1, 4, 2, 1, 4, 1, 1, 2, 2, 0, 2, 2,
#        2, 2, 4, 3, 0, 1, 0, 1, 4, 3, 0, 1, 1, 0, 2, 1, 0, 1, 1, 0, 1, 1,
#        2, 2, 0, 2, 2, 2, 1, 1, 2, 4, 1, 1, 3, 4, 0, 1, 2, 2, 1, 1, 1, 2,
#        1, 1, 4, 1, 1, 4, 1, 0, 1, 3, 4, 1, 2, 1, 1, 0, 3, 1, 2, 1, 1, 2,
#        4, 3, 2, 1, 2, 1, 2, 2, 1, 1, 1, 0, 1, 1, 1, 0, 3, 3, 2, 1, 2, 4,
#        1, 0, 3, 2, 2, 3, 0, 1, 4, 4, 1, 1, 1, 2, 1, 2, 2, 1, 0, 2, 2, 0,
#        2, 1, 1, 0, 0, 1, 2, 3, 3, 0, 2, 0, 3, 2, 1, 4, 1, 1, 2, 2, 1, 0,
#        2, 1, 1, 1, 0, 1])

# %%
actuals[:]
# Out:
# array([2, 1, 1, 0, 3, 2, 4, 2, 1, 0, 1, 4, 2, 1, 4, 1, 1, 0, 2, 0, 2, 1,
#        2, 2, 1, 3, 2, 1, 0, 1, 4, 3, 0, 1, 1, 0, 2, 1, 1, 1, 1, 0, 1, 1,
#        2, 1, 0, 2, 2, 1, 4, 1, 2, 4, 1, 0, 3, 4, 0, 1, 2, 2, 1, 1, 1, 2,
#        1, 1, 4, 1, 1, 4, 1, 0, 1, 3, 4, 1, 2, 1, 1, 3, 3, 1, 1, 1, 1, 0,
#        4, 0, 1, 2, 2, 0, 2, 2, 2, 1, 2, 1, 1, 1, 1, 0, 3, 1, 0, 1, 2, 4,
#        1, 0, 3, 0, 2, 3, 0, 1, 3, 4, 1, 1, 1, 3, 1, 2, 2, 1, 0, 2, 2, 2,
#        2, 1, 1, 0, 0, 1, 3, 0, 3, 0, 2, 0, 3, 2, 1, 1, 2, 1, 1, 2, 1, 0,
#        2, 1, 1, 1, 0, 2])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(actuals, predictions)
# Out:
# 0.8

# %%
örnek = test.iloc[56]['Release_Note']
print(örnek)
# Out:
# QSV Encoder: Improved performance when running OBS on an Intel GPU and simplified various options [brittneysclark],The cursor will now change to reflect your action (dragging edges or sources) when editing items in the preview [WizardCM],Improved the interface of transitions dock [cg2121],Increased the update rate of the level meters in the audio mixer from 30Hz to 60Hz for improved smoothness and responsiveness [dodgepong]

# %%
tahmin=model.predict([örnek])

if tahmin[0] ==0:
  print("new")
elif tahmin[0]==1:
  print("fixed")
elif tahmin[0]==2:
  print("changed")
elif tahmin[0]==3:
  print("other")
else:
  print("unresolved")
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# other
